# [youtube] 6XcmNHtx4ok: Downloading video info webpage
# [youtube] 6XcmNHtx4ok: Extracting video information
# [youtube] 6XcmNHtx4ok: Downloading MPD manifest
# [info] Writing video description metadata as JSON to: STONE COLD FOX - Hey, Look Over Here! Friday at 7_30-6XcmNHtx4ok.info.json
# [download] Downloading video 8 of 148
# [youtube] gbw6unOFClo: Downloading webpage
# [youtube] gbw6unOFClo: Downloading video info webpage
# [youtube] gbw6unOFClo: Extracting video information
# [youtube] gbw6unOFClo: Downloading MPD manifest
# [info] Writing video description metadata as JSON to: Jealous Boyfriend-gbw6unOFClo.info.json
# [download] Downloading video 9 of 148
# [youtube] 68N-RmMwv_s: Downloading webpage
# [youtube] 68N-RmMwv_s: Downloading video info webpage
# [youtube] 68N-RmMwv_s: Extracting video information
# [youtube] 68N-RmMwv_s: Downloading MPD manifest
# [youtube] 68N-RmMwv_s: Downloading MPD manifest
# [info] Writing video description metadata as JSON to: Suicideology-68N-RmMwv_s.info.json
# [download] Downloading video 10 of 148
# [youtube] RCA3nOQK0v0: Downloading webpage
# [youtube] RCA3nOQK0v0: Downloading video info webpage
# [youtube] RCA3nOQK0v0: Extracting video information
# [youtube] RCA3nOQK0v0: Downloading MPD manifest
# [info] Writing video description metadata as JSON to: UCB Maude Night 5_16_2011 - Pep Talk-RCA3nOQK0v0.info.json
# [download] Downloading video 11 of 148
# [youtube] Mv309_n1Zn4: Downloading webpage
# [youtube] Mv309_n1Zn4: Downloading video info webpage
# [youtube] Mv309_n1Zn4: Extracting video information
# [youtube] Mv309_n1Zn4: Downloading MPD manifest
# [youtube] Mv309_n1Zn4: Downloading MPD manifest
# [info] Writing video description metadata as JSON to: UCB Maude Night 5_16_2011 - Rock People-Mv309_n1Zn4.info.json
# [download] Downloading video 12 of 148
# [youtube] _2S35NoLjNI: Downloading webpage
# [youtube] _2S35NoLjNI: Downloading video info webpage
# [youtube] _2S35NoLjNI: Extracting video information
# [youtube] _2S35NoLjNI: Downloading MPD manifest
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7aac23e8b270> in <module>()
#       3 import youtube_dl
#       4 with youtube_dl.YoutubeDL(ydl_opts) as ydl:
# ----> 5     ydl.download(['https://www.youtube.com/user/StoneColdFoxSketch'])
#
# B:\Python27\lib\site-packages\youtube_dl\YoutubeDL.pyc in download(self, url_list)
#    1882                 # It also downloads the videos
#    1883                 res = self.extract_info(
# -> 1884                     url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    1885             except UnavailableVideoError:
#    1886                 self.report_error('unable to download video')
#
# B:\Python27\lib\site-packages\youtube_dl\YoutubeDL.pyc in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#     770                 self.add_default_extra_info(ie_result, ie, url)
#     771                 if process:
# --> 772                     return self.process_ie_result(ie_result, download, extra_info)
#     773                 else:
#     774                     return ie_result
#
# B:\Python27\lib\site-packages\youtube_dl\YoutubeDL.pyc in process_ie_result(self, ie_result, download, extra_info)
#     831                                      download,
#     832                                      ie_key=ie_result.get('ie_key'),
# --> 833                                      extra_info=extra_info)
#     834         elif result_type == 'url_transparent':
#     835             # Use the information from the embedding page
#
# B:\Python27\lib\site-packages\youtube_dl\YoutubeDL.pyc in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#     770                 self.add_default_extra_info(ie_result, ie, url)
#     771                 if process:
# --> 772                     return self.process_ie_result(ie_result, download, extra_info)
#     773                 else:
#     774                     return ie_result
#
# B:\Python27\lib\site-packages\youtube_dl\YoutubeDL.pyc in process_ie_result(self, ie_result, download, extra_info)
#     948                 entry_result = self.process_ie_result(entry,
#     949                                                       download=download,
# --> 950                                                       extra_info=extra)
#     951                 playlist_results.append(entry_result)
#     952             ie_result['entries'] = playlist_results
#
# B:\Python27\lib\site-packages\youtube_dl\YoutubeDL.pyc in process_ie_result(self, ie_result, download, extra_info)
#     831                                      download,
#     832                                      ie_key=ie_result.get('ie_key'),
# --> 833                                      extra_info=extra_info)
#     834         elif result_type == 'url_transparent':
#     835             # Use the information from the embedding page
#
# B:\Python27\lib\site-packages\youtube_dl\YoutubeDL.pyc in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#     759
#     760             try:
# --> 761                 ie_result = ie.extract(url)
#     762                 if ie_result is None:  # Finished already (backwards compatibility; listformats and friends should be moved here)
#     763                     break
#
# B:\Python27\lib\site-packages\youtube_dl\extractor\common.pyc in extract(self, url)
#     426                 try:
#     427                     self.initialize()
# --> 428                     ie_result = self._real_extract(url)
#     429                     if self._x_forwarded_for_ip:
#     430                         ie_result['__x_forwarded_for_ip'] = self._x_forwarded_for_ip
#
# B:\Python27\lib\site-packages\youtube_dl\extractor\youtube.pyc in _real_extract(self, url)
#    1736                     for df in self._extract_mpd_formats(
#    1737                             mpd_url, video_id, fatal=dash_mpd_fatal,
# -> 1738                             formats_dict=self._formats):
#    1739                         # Do not overwrite DASH format found in some previous DASH manifest
#    1740                         if df['format_id'] not in dash_formats:
#
# B:\Python27\lib\site-packages\youtube_dl\extractor\common.pyc in _extract_mpd_formats(self, mpd_url, video_id, mpd_id, note, errnote, fatal, formats_dict)
#    1659             note=note or 'Downloading MPD manifest',
#    1660             errnote=errnote or 'Failed to download MPD manifest',
# -> 1661             fatal=fatal)
#    1662         if res is False:
#    1663             return []
#
# B:\Python27\lib\site-packages\youtube_dl\extractor\common.pyc in _download_webpage_handle(self, url_or_request, video_id, note, errnote, fatal, encoding, data, headers, query)
#     524                 headers['X-Forwarded-For'] = self._x_forwarded_for_ip
#     525
# --> 526         urlh = self._request_webpage(url_or_request, video_id, note, errnote, fatal, data=data, headers=headers, query=query)
#     527         if urlh is False:
#     528             assert not fatal
#
# B:\Python27\lib\site-packages\youtube_dl\extractor\common.pyc in _request_webpage(self, url_or_request, video_id, note, errnote, fatal, data, headers, query)
#     495                 url_or_request = sanitized_Request(url_or_request, data, headers)
#     496         try:
# --> 497             return self._downloader.urlopen(url_or_request)
#     498         except (compat_urllib_error.URLError, compat_http_client.HTTPException, socket.error) as err:
#     499             if errnote is False:
#
# B:\Python27\lib\site-packages\youtube_dl\YoutubeDL.pyc in urlopen(self, req)
#    2092         if isinstance(req, compat_basestring):
#    2093             req = sanitized_Request(req)
# -> 2094         return self._opener.open(req, timeout=self._socket_timeout)
#    2095
#    2096     def print_debug_header(self):
#
# B:\Python27\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     389             req = meth(req)
#     390
# --> 391         response = self._open(req, data)
#     392
#     393         # post-process response
#
# B:\Python27\lib\urllib2.pyc in _open(self, req, data)
#     407         protocol = req.get_type()
#     408         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 409                                   '_open', req)
#     410         if result:
#     411             return result
#
# B:\Python27\lib\urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     367             func = getattr(handler, meth_name)
#     368
# --> 369             result = func(*args)
#     370             if result is not None:
#     371                 return result
#
# B:\Python27\lib\site-packages\youtube_dl\utils.pyc in https_open(self, req)
#    1081         return self.do_open(functools.partial(
#    1082             _create_http_connection, self, conn_class, True),
# -> 1083             req, **kwargs)
#    1084
#    1085
#
# B:\Python27\lib\urllib2.pyc in do_open(self, http_class, req)
#    1142             h.request(req.get_method(), req.get_selector(), req.data, headers)
#    1143             try:
# -> 1144                 r = h.getresponse(buffering=True)
#    1145             except TypeError: #buffering kw not supported
#    1146                 r = h.getresponse()
#
# B:\Python27\lib\httplib.pyc in getresponse(self, buffering)
#    1023         response = self.response_class(*args, **kwds)
#    1024
# -> 1025         response.begin()
#    1026         assert response.will_close != _UNKNOWN
#    1027         self.__state = _CS_IDLE
#
# B:\Python27\lib\httplib.pyc in begin(self)
#     399         # read until we get a non-100 response
#     400         while True:
# --> 401             version, status, reason = self._read_status()
#     402             if status != CONTINUE:
#     403                 break
#
# B:\Python27\lib\httplib.pyc in _read_status(self)
#     357     def _read_status(self):
#     358         # Initialize with Simple-Response defaults
# --> 359         line = self.fp.readline()
#     360         if self.debuglevel > 0:
#     361             print "reply:", repr(line)
#
# B:\Python27\lib\socket.pyc in readline(self, size)
#     443             while True:
#     444                 try:
# --> 445                     data = self._sock.recv(self._rbufsize)
#     446                 except error, e:
#     447                     if e.args[0] == EINTR:
#
# B:\Python27\lib\ssl.pyc in recv(self, buflen, flags)
#     215                     "non-zero flags not allowed in calls to recv() on %s" %
#     216                     self.__class__)
# --> 217             return self.read(buflen)
#     218         else:
#     219             return socket.recv(self, buflen, flags)
#
# B:\Python27\lib\ssl.pyc in read(self, len)
#     136
#     137         try:
# --> 138             return self._sslobj.read(len)
#     139         except SSLError, x:
#     140             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
