# %%
directory
os.path.exists(directory)
# Out:
# True

# %%
import os
for team in maude_youtubes.keys():
    directory = r'B:\Projects\maude\%s' % team
    print directory
    if not os.path.exists(directory):
        print 'amde'
        os.makedirs(directory)
# Out:
# B:\Projects\maude\Roanoke
# amde
# B:\Projects\maude\212
# amde
# B:\Projects\maude\Pretty_Boys
# amde
# B:\Projects\maude\Lover
# amde
# B:\Projects\maude\Monaco
# amde
# B:\Projects\maude\Choir
# amde
# B:\Projects\maude\Alamo
# amde
# B:\Projects\maude\Prom
# amde
# B:\Projects\maude\Ripley
# amde
# B:\Projects\maude\Stone_Cold_Fox
# amde
# B:\Projects\maude\Beige
# amde
# B:\Projects\maude\Archnemesis
# amde
# B:\Projects\maude\Legs_for_Days
# amde
# B:\Projects\maude\Goodbye_Handsome
# amde
# B:\Projects\maude\27 Kidneys
# amde
# B:\Projects\maude\One_Idiot
# amde
# B:\Projects\maude\The_Foundation
# amde
# B:\Projects\maude\Bellevue
# amde
# B:\Projects\maude\Hot_Bird
# amde
# B:\Projects\maude\Onassis
# amde
# B:\Projects\maude\Charles
# amde
# B:\Projects\maude\Cha-Cha
# amde
# B:\Projects\maude\Dangerous_Woman
# amde
# B:\Projects\maude\Bundt
# B:\Projects\maude\Mamas_Gotta_Go
# amde
# B:\Projects\maude\Estevez
# amde
# B:\Projects\maude\Nipsey
# amde
# ...

# %%
directory = os.path.join('B:%s' %os.sep,'Projects', 'maude')

# %%
directory
# Out:
# 'B:\\Projects\\maude'

# %%
for team, link in maude_youtubes.iteritems():
    team_dir =  os.path.join(directory,team)
    ydl_opts = {
        'skip_download':True,
               'writeinfojson':True,
               'outtmpl': team_dir+'\\%(title)s.%(ext)s',
                'download_archive':directory+'\\archive.txt',
                'ignoreerrors':True
               }
    with youtube_dl.YoutubeDL(ydl_opts) as ydl:
        ydl.download([link])
# Out:
# WARNING: Parameter outtmpl is bytes, but should be a unicode string. Put  from __future__ import unicode_literals  at the top of your code file or consider switching to Python 3.x.
# [youtube:channel] UCEaHDYX1spL5CFXJcoKbENg: Downloading channel page
# [youtube:playlist] UUEaHDYX1spL5CFXJcoKbENg: Downloading webpage
# [download] Downloading playlist: Uploads from Roanoke
# [youtube:playlist] playlist Uploads from Roanoke: Downloading 47 videos
# [download] Downloading video 1 of 47
# [youtube] eRxVBbFpi0I: Downloading webpage
# [youtube] eRxVBbFpi0I: Downloading video info webpage
# [youtube] eRxVBbFpi0I: Extracting video information
# [youtube] eRxVBbFpi0I: Downloading MPD manifest
# [info] Writing video description metadata as JSON to: B:\Projects\maude\Roanoke\Sister Sister (ROANOKE Oct 2015).info.json
# [download] Downloading video 2 of 47
# [youtube] XXrml1-3p0k: Downloading webpage
# [youtube] XXrml1-3p0k: Downloading video info webpage
# ...

# %%
team_dir
# Out:
# 'B:\\Projects\\maude\\Bellevue'
